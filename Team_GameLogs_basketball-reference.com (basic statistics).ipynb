# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup, Comment 
import pandas as pd
import html5lib
import time 
import requests
import re

# %%
# URL for team stats 
url_template_team = "http://www.basketball-reference.com/teams/{team}/{year}/gamelog/"

# %%
# teams
teams = ["LAL", "BOS", "DEN", "DAL", "DET", "SAC", "WAS", "WSB", "GSW", "SAS", "POR", "PHI", "NJN", "BRK", "UTA", "OKC", 
         "SEA", "LAC", "ATL", "HOU", "CHA", "CHH", "CHO", "MIL", "NYK", "CHI", "PHO", "MIA", "CLE", "IND", "ORL", "MIN", 
         "MEM", "VAN", "TOR", "NOH", "NOK", "NOP"]

# %%
# function to get column headers (pass in the url and the row at which the column headers begin)
def get_columns(url_column, row):
    
    # get the HTML from the url passed in 
    html = urlopen(url_column)
    
    # make a BS object
    soup = BeautifulSoup(html, "lxml")
    
    # find all the tr tags for the column header of interest 
    tr_tag_list = soup.findAll('tr')[row-1] 
    
    # extract table header cell elements from the tag object
    cell_el_list = tr_tag_list.findAll('th')

    # create an empty list to hold all the elements in the column header 
    column_headers = []  

    # for each cell element
    for th in cell_el_list:  
        col_element = th.getText()
        # append each cell element to the column_header list
        column_headers.append(col_element)
    return column_headers

# %%
column_teams = get_columns("http://www.basketball-reference.com/teams/ATL/1975/gamelog/", 2)

# %%
# function to run through multiple years and multiple teams and get the regular season game logs 
def get_game_logs(url_curr, column_headers, teams, start, end):
    
    # create an empty DataFrame to store all the game logs for all the team's seasons 
    team_stats_df = pd.DataFrame()
    
    for team in teams:
        for year in range(start, end):
            # get the url
            url = url_curr.format(team=team, year=year)
        
            # check if there are game logs for the current team and the current season
            try:
                html = urlopen(url)
            except:
                print("No data for " + team + " in the " + str(year) + " season" + " in the regular season")
                continue
                
            # get the html
            html = urlopen(url)
            # create the beautiful soup object 
            soup = BeautifulSoup(html, "lxml")
            
            ### PART 1: REGULAR SEASON DATA 
    
            # get regular season data (starts on second row)
            data_rows = soup.findAll('tr')[1:]
            
            # check if data_rows actually contains data
            if len(data_rows)<1:
                print("No data for " + team + " in the " + str(year) + " season" + " in the regular season")
                continue 

            # create an empty list to hold all the regular season stats for the current season and the current team 
            season_data = []  

            for i in range(len(data_rows)):
                # create an empty list for each game 
                game_row = []
            
                # first value. Must be handled separately since it goes by th tag instead of td tag 
                game_row.append(data_rows[i].findAll('th')[0].getText())

                # for each table data element from each table row
                for td in data_rows[i].findAll('td'):        
                    # get the text content and append to the game_row 
                    game_row.append(td.getText())        

                # then append each game to the season_data matrix
                season_data.append(game_row)
            
            # Turn season data into a DatFrame
            season_df = pd.DataFrame(season_data, columns=column_headers)
            # Add game_type column
            season_df.insert(0, 'GameType', 'RegularSeason')
                
            ### PART 2: PLAYOFF DATA
            
            # get all the comments on the page
            comments=soup.find_all(string=lambda text:isinstance(text,Comment))
            
            # create an empty list to hold all the playoff stats for the current season and the current team 
            season_data_2 = []
            
            for comment in comments:
                comment_soup = BeautifulSoup(comment, "lxml")
                # print(len(comment_soup.find_all("table")))
                # check if the team has playoffs data
                if(len(comment_soup.find_all("table"))>0):
                    for table in comment_soup.find_all("table"):
                        data_rows_2 = table.findAll('tr')[2:]
                        
                        for i in range(len(data_rows_2)):
                            game_row_2 = []
                            game_row_2.append(data_rows_2[i].findAll('th')[0].getText())
                            for td_2 in data_rows_2[i].findAll('td'):
                                game_row_2.append(td_2.getText())
            
                            season_data_2.append(game_row_2)
            
                        season_2_df = pd.DataFrame(season_data_2, columns=column_teams)
                        season_2_df.insert(0, 'GameType', 'Playoffs')
                    # exit the loop after it finds the playoff data 
                    break
                else:
                    # no playoff data
                    season_2_df = pd.DataFrame()
                    continue 
        
            # combine the regular season data frame with the playoffs data frame
            all_season_df = season_df.append(season_2_df)
            
            # create and insert the Season and Team column
            all_season_df.insert(1, 'Season', year)
            all_season_df.insert(2, 'Team', team)
        
            # Append to the big dataframe
            team_stats_df = team_stats_df.append(all_season_df, ignore_index=True)

    return team_stats_df

# %%
start_time = time.time()

# call function for game logs 
team_game_logs_df = get_game_logs(url_template_team, column_teams, teams, 1987, 2018)

print("%f seconds" % (time.time() - start_time))
# Out:
# No data for WAS in the 1987 season in the regular season
# No data for WAS in the 1988 season in the regular season
# No data for WAS in the 1989 season in the regular season
# No data for WAS in the 1990 season in the regular season
# No data for WAS in the 1991 season in the regular season
# No data for WAS in the 1992 season in the regular season
# No data for WAS in the 1993 season in the regular season
# No data for WAS in the 1994 season in the regular season
# No data for WAS in the 1995 season in the regular season
# No data for WAS in the 1996 season in the regular season
# No data for WAS in the 1997 season in the regular season
# No data for WSB in the 1998 season in the regular season
# No data for WSB in the 1999 season in the regular season
# No data for WSB in the 2000 season in the regular season
# No data for WSB in the 2001 season in the regular season
# No data for WSB in the 2002 season in the regular season
# No data for WSB in the 2003 season in the regular season
# No data for WSB in the 2004 season in the regular season
# No data for WSB in the 2005 season in the regular season
# No data for WSB in the 2006 season in the regular season
# No data for WSB in the 2007 season in the regular season
# No data for WSB in the 2008 season in the regular season
# No data for WSB in the 2009 season in the regular season
# No data for WSB in the 2010 season in the regular season
# No data for WSB in the 2011 season in the regular season
# No data for WSB in the 2012 season in the regular season
# No data for WSB in the 2013 season in the regular season
# No data for WSB in the 2014 season in the regular season
# No data for WSB in the 2015 season in the regular season
# No data for WSB in the 2016 season in the regular season
# No data for WSB in the 2017 season in the regular season
# No data for NJN in the 2013 season in the regular season
# No data for NJN in the 2014 season in the regular season
# No data for NJN in the 2015 season in the regular season
# No data for NJN in the 2016 season in the regular season
# No data for NJN in the 2017 season in the regular season
# No data for BRK in the 1987 season in the regular season
# No data for BRK in the 1988 season in the regular season
# No data for BRK in the 1989 season in the regular season
# No data for BRK in the 1990 season in the regular season
# No data for BRK in the 1991 season in the regular season
# No data for BRK in the 1992 season in the regular season
# No data for BRK in the 1993 season in the regular season
# No data for BRK in the 1994 season in the regular season
# No data for BRK in the 1995 season in the regular season
# No data for BRK in the 1996 season in the regular season
# No data for BRK in the 1997 season in the regular season
# No data for BRK in the 1998 season in the regular season
# No data for BRK in the 1999 season in the regular season
# No data for BRK in the 2000 season in the regular season
# No data for BRK in the 2001 season in the regular season
# No data for BRK in the 2002 season in the regular season
# No data for BRK in the 2003 season in the regular season
# No data for BRK in the 2004 season in the regular season
# No data for BRK in the 2005 season in the regular season
# No data for BRK in the 2006 season in the regular season
# No data for BRK in the 2007 season in the regular season
# No data for BRK in the 2008 season in the regular season
# No data for BRK in the 2009 season in the regular season
# No data for BRK in the 2010 season in the regular season
# No data for BRK in the 2011 season in the regular season
# No data for BRK in the 2012 season in the regular season
# No data for OKC in the 1987 season in the regular season
# No data for OKC in the 1988 season in the regular season
# No data for OKC in the 1989 season in the regular season
# No data for OKC in the 1990 season in the regular season
# No data for OKC in the 1991 season in the regular season
# No data for OKC in the 1992 season in the regular season
# No data for OKC in the 1993 season in the regular season
# No data for OKC in the 1994 season in the regular season
# No data for OKC in the 1995 season in the regular season
# No data for OKC in the 1996 season in the regular season
# No data for OKC in the 1997 season in the regular season
# No data for OKC in the 1998 season in the regular season
# No data for OKC in the 1999 season in the regular season
# No data for OKC in the 2000 season in the regular season
# No data for OKC in the 2001 season in the regular season
# No data for OKC in the 2002 season in the regular season
# No data for OKC in the 2003 season in the regular season
# No data for OKC in the 2004 season in the regular season
# No data for OKC in the 2005 season in the regular season
# No data for OKC in the 2006 season in the regular season
# No data for OKC in the 2007 season in the regular season
# No data for OKC in the 2008 season in the regular season
# No data for SEA in the 2009 season in the regular season
# No data for SEA in the 2010 season in the regular season
# No data for SEA in the 2011 season in the regular season
# No data for SEA in the 2012 season in the regular season
# No data for SEA in the 2013 season in the regular season
# No data for SEA in the 2014 season in the regular season
# No data for SEA in the 2015 season in the regular season
# No data for SEA in the 2016 season in the regular season
# No data for SEA in the 2017 season in the regular season
# No data for CHA in the 1987 season in the regular season
# No data for CHA in the 1988 season in the regular season
# No data for CHA in the 1989 season in the regular season
# No data for CHA in the 1990 season in the regular season
# No data for CHA in the 1991 season in the regular season
# No data for CHA in the 1992 season in the regular season
# No data for CHA in the 1993 season in the regular season
# No data for CHA in the 1994 season in the regular season
# No data for CHA in the 1995 season in the regular season
# No data for CHA in the 1996 season in the regular season
# No data for CHA in the 1997 season in the regular season
# No data for CHA in the 1998 season in the regular season
# No data for CHA in the 1999 season in the regular season
# No data for CHA in the 2000 season in the regular season
# No data for CHA in the 2001 season in the regular season
# No data for CHA in the 2002 season in the regular season
# No data for CHA in the 2003 season in the regular season
# No data for CHA in the 2004 season in the regular season
# No data for CHA in the 2015 season in the regular season
# No data for CHA in the 2016 season in the regular season
# No data for CHA in the 2017 season in the regular season
# No data for CHH in the 1987 season in the regular season
# No data for CHH in the 1988 season in the regular season
# No data for CHH in the 2003 season in the regular season
# No data for CHH in the 2004 season in the regular season
# No data for CHH in the 2005 season in the regular season
# No data for CHH in the 2006 season in the regular season
# No data for CHH in the 2007 season in the regular season
# No data for CHH in the 2008 season in the regular season
# No data for CHH in the 2009 season in the regular season
# No data for CHH in the 2010 season in the regular season
# No data for CHH in the 2011 season in the regular season
# No data for CHH in the 2012 season in the regular season
# No data for CHH in the 2013 season in the regular season
# No data for CHH in the 2014 season in the regular season
# No data for CHH in the 2015 season in the regular season
# No data for CHH in the 2016 season in the regular season
# No data for CHH in the 2017 season in the regular season
# No data for CHO in the 1987 season in the regular season
# No data for CHO in the 1988 season in the regular season
# No data for CHO in the 1989 season in the regular season
# No data for CHO in the 1990 season in the regular season
# No data for CHO in the 1991 season in the regular season
# No data for CHO in the 1992 season in the regular season
# No data for CHO in the 1993 season in the regular season
# No data for CHO in the 1994 season in the regular season
# No data for CHO in the 1995 season in the regular season
# No data for CHO in the 1996 season in the regular season
# No data for CHO in the 1997 season in the regular season
# No data for CHO in the 1998 season in the regular season
# No data for CHO in the 1999 season in the regular season
# No data for CHO in the 2000 season in the regular season
# No data for CHO in the 2001 season in the regular season
# No data for CHO in the 2002 season in the regular season
# No data for CHO in the 2003 season in the regular season
# No data for CHO in the 2004 season in the regular season
# No data for CHO in the 2005 season in the regular season
# No data for CHO in the 2006 season in the regular season
# No data for CHO in the 2007 season in the regular season
# No data for CHO in the 2008 season in the regular season
# No data for CHO in the 2009 season in the regular season
# No data for CHO in the 2010 season in the regular season
# No data for CHO in the 2011 season in the regular season
# No data for CHO in the 2012 season in the regular season
# No data for CHO in the 2013 season in the regular season
# No data for CHO in the 2014 season in the regular season
# No data for MIA in the 1987 season in the regular season
# No data for MIA in the 1988 season in the regular season
# No data for ORL in the 1987 season in the regular season
# No data for ORL in the 1988 season in the regular season
# No data for ORL in the 1989 season in the regular season
# No data for MIN in the 1987 season in the regular season
# No data for MIN in the 1988 season in the regular season
# No data for MIN in the 1989 season in the regular season
# No data for MEM in the 1987 season in the regular season
# No data for MEM in the 1988 season in the regular season
# No data for MEM in the 1989 season in the regular season
# No data for MEM in the 1990 season in the regular season
# No data for MEM in the 1991 season in the regular season
# No data for MEM in the 1992 season in the regular season
# No data for MEM in the 1993 season in the regular season
# No data for MEM in the 1994 season in the regular season
# No data for MEM in the 1995 season in the regular season
# No data for MEM in the 1996 season in the regular season
# No data for MEM in the 1997 season in the regular season
# No data for MEM in the 1998 season in the regular season
# No data for MEM in the 1999 season in the regular season
# No data for MEM in the 2000 season in the regular season
# No data for MEM in the 2001 season in the regular season
# No data for VAN in the 1987 season in the regular season
# No data for VAN in the 1988 season in the regular season
# No data for VAN in the 1989 season in the regular season
# No data for VAN in the 1990 season in the regular season
# No data for VAN in the 1991 season in the regular season
# No data for VAN in the 1992 season in the regular season
# No data for VAN in the 1993 season in the regular season
# No data for VAN in the 1994 season in the regular season
# No data for VAN in the 1995 season in the regular season
# No data for VAN in the 2002 season in the regular season
# No data for VAN in the 2003 season in the regular season
# No data for VAN in the 2004 season in the regular season
# No data for VAN in the 2005 season in the regular season
# No data for VAN in the 2006 season in the regular season
# No data for VAN in the 2007 season in the regular season
# No data for VAN in the 2008 season in the regular season
# No data for VAN in the 2009 season in the regular season
# No data for VAN in the 2010 season in the regular season
# No data for VAN in the 2011 season in the regular season
# No data for VAN in the 2012 season in the regular season
# No data for VAN in the 2013 season in the regular season
# No data for VAN in the 2014 season in the regular season
# No data for VAN in the 2015 season in the regular season
# No data for VAN in the 2016 season in the regular season
# No data for VAN in the 2017 season in the regular season
# No data for TOR in the 1987 season in the regular season
# No data for TOR in the 1988 season in the regular season
# No data for TOR in the 1989 season in the regular season
# No data for TOR in the 1990 season in the regular season
# No data for TOR in the 1991 season in the regular season
# No data for TOR in the 1992 season in the regular season
# No data for TOR in the 1993 season in the regular season
# No data for TOR in the 1994 season in the regular season
# No data for TOR in the 1995 season in the regular season
# No data for NOH in the 1987 season in the regular season
# No data for NOH in the 1988 season in the regular season
# No data for NOH in the 1989 season in the regular season
# No data for NOH in the 1990 season in the regular season
# No data for NOH in the 1991 season in the regular season
# No data for NOH in the 1992 season in the regular season
# No data for NOH in the 1993 season in the regular season
# No data for NOH in the 1994 season in the regular season
# No data for NOH in the 1995 season in the regular season
# No data for NOH in the 1996 season in the regular season
# No data for NOH in the 1997 season in the regular season
# No data for NOH in the 1998 season in the regular season
# No data for NOH in the 1999 season in the regular season
# No data for NOH in the 2000 season in the regular season
# No data for NOH in the 2001 season in the regular season
# No data for NOH in the 2002 season in the regular season
# No data for NOH in the 2006 season in the regular season
# No data for NOH in the 2007 season in the regular season
# No data for NOH in the 2014 season in the regular season
# No data for NOH in the 2015 season in the regular season
# No data for NOH in the 2016 season in the regular season
# No data for NOH in the 2017 season in the regular season
# No data for NOK in the 1987 season in the regular season
# No data for NOK in the 1988 season in the regular season
# No data for NOK in the 1989 season in the regular season
# No data for NOK in the 1990 season in the regular season
# No data for NOK in the 1991 season in the regular season
# No data for NOK in the 1992 season in the regular season
# No data for NOK in the 1993 season in the regular season
# No data for NOK in the 1994 season in the regular season
# No data for NOK in the 1995 season in the regular season
# No data for NOK in the 1996 season in the regular season
# No data for NOK in the 1997 season in the regular season
# No data for NOK in the 1998 season in the regular season
# No data for NOK in the 1999 season in the regular season
# No data for NOK in the 2000 season in the regular season
# No data for NOK in the 2001 season in the regular season
# No data for NOK in the 2002 season in the regular season
# No data for NOK in the 2003 season in the regular season
# No data for NOK in the 2004 season in the regular season
# No data for NOK in the 2005 season in the regular season
# No data for NOK in the 2008 season in the regular season
# No data for NOK in the 2009 season in the regular season
# No data for NOK in the 2010 season in the regular season
# No data for NOK in the 2011 season in the regular season
# No data for NOK in the 2012 season in the regular season
# No data for NOK in the 2013 season in the regular season
# No data for NOK in the 2014 season in the regular season
# No data for NOK in the 2015 season in the regular season
# No data for NOK in the 2016 season in the regular season
# No data for NOK in the 2017 season in the regular season
# No data for NOP in the 1987 season in the regular season
# No data for NOP in the 1988 season in the regular season
# No data for NOP in the 1989 season in the regular season
# No data for NOP in the 1990 season in the regular season
# No data for NOP in the 1991 season in the regular season
# No data for NOP in the 1992 season in the regular season
# No data for NOP in the 1993 season in the regular season
# No data for NOP in the 1994 season in the regular season
# No data for NOP in the 1995 season in the regular season
# No data for NOP in the 1996 season in the regular season
# No data for NOP in the 1997 season in the regular season
# No data for NOP in the 1998 season in the regular season
# No data for NOP in the 1999 season in the regular season
# No data for NOP in the 2000 season in the regular season
# No data for NOP in the 2001 season in the regular season
# No data for NOP in the 2002 season in the regular season
# No data for NOP in the 2003 season in the regular season
# No data for NOP in the 2004 season in the regular season
# No data for NOP in the 2005 season in the regular season
# No data for NOP in the 2006 season in the regular season
# No data for NOP in the 2007 season in the regular season
# No data for NOP in the 2008 season in the regular season
# No data for NOP in the 2009 season in the regular season
# No data for NOP in the 2010 season in the regular season
# No data for NOP in the 2011 season in the regular season
# No data for NOP in the 2012 season in the regular season
# No data for NOP in the 2013 season in the regular season
# 6482.221913 seconds

# %%
# look at number of rows
len(team_game_logs_df)
# Out:
# 83724

# %%
# look at first few rows 
team_game_logs_df.head()
# Out:
#         GameType  Season Team  Rk     G        Date         Opp   W/L    Tm  \
# 0  RegularSeason    1987  LAL  Rk  None        None  None  None  None  None
# 1  RegularSeason    1987  LAL   1     1  1986-11-01     @   HOU     L   102
# 2  RegularSeason    1987  LAL   2     2  1986-11-04     @   SEA     W   110
# 3  RegularSeason    1987  LAL   3     3  1986-11-07         DEN     W   138
# 4  RegularSeason    1987  LAL   4     4  1986-11-09         NYK     W   111
#
#    ...     FT   FTA   FT%   ORB   TRB   AST   STL   BLK   TOV    PF
# 0  ...   None  None  None  None  None  None  None  None  None  None
# 1  ...     21    34  .618    13    35    27     7     6    11    22
# 2  ...     20    25  .800    19    44    24    12     4    19    26
# 3  ...     23    28  .821     5    33    33     5     1    19    25
# 4  ...     20    23  .870     8    39    20     8     7    22    22
#
# [5 rows x 44 columns]

# %%
# look at last few rows 
team_game_logs_df.tail()
# Out:
#             GameType  Season Team  Rk     G        Date         Opp   W/L  \
# 83719  RegularSeason    2017  NOP  80    80  2017-04-08     @   GSW     L
# 83720  RegularSeason    2017  NOP      None        None  None  None  None
# 83721  RegularSeason    2017  NOP  Rk  None        None  None  None  None
# 83722  RegularSeason    2017  NOP  81    81  2017-04-11     @   LAL     L
# 83723  RegularSeason    2017  NOP  82    82  2017-04-12     @   POR     W
#
#          Tm  ...     FT   FTA   FT%   ORB   TRB   AST   STL   BLK   TOV    PF
# 83719   101  ...     15    16  .938    14    53    37     2     4     9    15
# 83720  None  ...   None  None  None  None  None  None  None  None  None  None
# 83721  None  ...   None  None  None  None  None  None  None  None  None  None
# 83722    96  ...     16    23  .696     8    47    24    15     3    11    18
# 83723   103  ...      5    13  .385    14    53    22     4     2    23    18
#
# [5 rows x 44 columns]

# %%
# function to clean data
def clean_df(df):
    # Convert data to proper data types
    df = df.convert_objects(convert_numeric=True)

    # Get rid of the rows full of null values
    df = df[df.Season.notnull()]

    # Replace NaNs with 0s
    df = df.fillna(0)
    
    # Change % symbol
    df.columns = df.columns.str.replace('%', '_Perc')
    
    return df

# %%
# clean advanced player stats df
team_game_logs_df = clean_df(team_game_logs_df)
# Out:
# /Users/gordondri/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
team_game_logs_df.columns
# Out:
# Index(['GameType', 'Season', 'Team', 'Rk', 'G', 'Date', ' ', 'Opp', 'W/L',
#        'Tm', 'Opp', 'FG', 'FGA', 'FG_Perc', '3P', '3PA', '3P_Perc', 'FT',
#        'FTA', 'FT_Perc', 'ORB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', ' ',
#        'FG', 'FGA', 'FG_Perc', '3P', '3PA', '3P_Perc', 'FT', 'FTA', 'FT_Perc',
#        'ORB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF'],
#       dtype='object')

# %%
# Check if missing values in the DataFrame
team_game_logs_df.isnull().sum()
# Out:
# GameType    0
# Season      0
# Team        0
# Rk          0
# G           0
# Date        0
#             0
# Opp         0
# W/L         0
# Tm          0
# Opp         0
# FG          0
# FGA         0
# FG_Perc     0
# 3P          0
# 3PA         0
# 3P_Perc     0
# FT          0
# FTA         0
# FT_Perc     0
# ORB         0
# TRB         0
# AST         0
# STL         0
# BLK         0
# TOV         0
# PF          0
#             0
# FG          0
# FGA         0
# FG_Perc     0
# 3P          0
# 3PA         0
# 3P_Perc     0
# FT          0
# FTA         0
# FT_Perc     0
# ORB         0
# TRB         0
# AST         0
# STL         0
# BLK         0
# TOV         0
# PF          0
# dtype: int64

# %%
# write data frame to CSV
team_game_logs_df.to_csv("team_game_logs_basic_1987_2017.csv")
